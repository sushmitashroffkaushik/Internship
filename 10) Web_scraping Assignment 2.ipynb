# %%
# Question 1

import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
import time
import pandas as pd

driver = None
def init_driver(url):
  global driver
  try:
    options = webdriver.ChromeOptions()
    options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36")
    driver = webdriver.Chrome(options=options)
    driver.get(url)
  except Exception as e:
    print("Error:", e)
  return driver

def perform_search():
  input_box = driver.find_element(By.CSS_SELECTOR, "#webSearchBar input")
  input_box.click()
  time.sleep(1)
  input_box = driver.find_element(By.ID, "id_q")
  input_box.send_keys("Data Analyst")
  input_box = driver.find_element(By.ID, "id_loc")
  input_box.send_keys("Bangalore")
  input_box.send_keys(Keys.ENTER)
  try:
    WebDriverWait(driver, 3).until(
      EC.presence_of_element_located((By.CLASS_NAME, "register_close"))
    )
    close_btn = driver.find_element(By.CLASS_NAME, "register_close")
    close_btn.click()
  except:
    pass
  return None

def scrape_details():
  rows = driver.find_elements(By.CLASS_NAME, "jobCard")
  result = {
    "title": [],
    "company": [],
    "location": [],
    "experience": []
  }
  for index, row in enumerate(rows):
    if index >= 10:
      break
    job_title = row.find_element(By.TAG_NAME, "h2").text.strip()
    company_name = row.find_element(By.CLASS_NAME, "jobCard_jobCard_cName__mYnow").text.strip()
    job_location = re.sub(r'[^a-zA-Z]', '', (row.find_element(By.CLASS_NAME, "jobCard_locationIcon__zrWt2").text).strip())
    job_experience = row.find_element(By.CLASS_NAME, "jobCard_jobIcon__3FB1t").text.strip()
    result["title"].append(job_title)
    result["company"].append(company_name)
    result["location"].append(job_location)
    result["experience"].append(job_experience)
  return result  

def main():
  try:
    init_driver("https://www.shine.com/")
    if driver:
      WebDriverWait(driver, 30).until(
        EC.presence_of_element_located((By.ID, "webSearchBar"))
      )
      perform_search()
      print(pd.DataFrame(scrape_details()))
  finally:
    if driver:
        driver.quit()

if __name__ == "__main__":
    main()
# Out:
#                                                title  \
# 0                                       Data Analyst
# 1                              Clinical Data Analyst
# 2                                       Data Analyst
# 3                                Azure Data engineer
# 4                            Hiring For Data Analyst
# 5                      GCP Data Engineer / Developer
# 6                              Clinical Data Analyst
# 7                                  Lead Data Analyst
# 8                       Data Operator all over India
# 9  Part Time Home Based Data Entry , all over Ind...
#
#                                   company   location    experience
# 0                sahast sales corporation  Bangalore  12 to 22 Yrs
# 1                           techno endura  Bangalore     0 to 1 Yr
# 2                sahast sales corporation  Bangalore  12 to 22 Yrs
# 3  capgemini technology services india...  Bangalore   6 to 10 Yrs
# ...

# %%
# Question 2

import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
import time
import pandas as pd

driver = None
def init_driver(url):
  global driver
  try:
    options = webdriver.ChromeOptions()
    options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36")
    driver = webdriver.Chrome(options=options)
    driver.get(url)
  except Exception as e:
    print("Error:", e)
  return driver

def perform_search():
  input_box = driver.find_element(By.CSS_SELECTOR, "#webSearchBar input")
  input_box.click()
  time.sleep(1)
  input_box = driver.find_element(By.ID, "id_q")
  input_box.send_keys("Data Scientist")
  input_box = driver.find_element(By.ID, "id_loc")
  input_box.send_keys("Bangalore")
  input_box.send_keys(Keys.ENTER)
  try:
    WebDriverWait(driver, 3).until(
      EC.presence_of_element_located((By.CLASS_NAME, "register_close"))
    )
    close_btn = driver.find_element(By.CLASS_NAME, "register_close")
    close_btn.click()
  except:
    pass
  return None

def scrape_details():
  rows = driver.find_elements(By.CLASS_NAME, "jobCard")
  result = {
    "title": [],
    "company": [],
    "location": [],
    "experience": []
  }
  for index, row in enumerate(rows):
    if index >= 10:
      break
    job_title = row.find_element(By.TAG_NAME, "h2").text.strip()
    company_name = row.find_element(By.CLASS_NAME, "jobCard_jobCard_cName__mYnow").text.strip()
    job_location = re.sub(r'[^a-zA-Z]', '', (row.find_element(By.CLASS_NAME, "jobCard_locationIcon__zrWt2").text).strip())
    job_experience = row.find_element(By.CLASS_NAME, "jobCard_jobIcon__3FB1t").text.strip()
    result["title"].append(job_title)
    result["company"].append(company_name)
    result["location"].append(job_location)
    result["experience"].append(job_experience)
  return result  

def main():
  try:
    init_driver("https://www.shine.com/")
    if driver:
      WebDriverWait(driver, 30).until(
        EC.presence_of_element_located((By.ID, "webSearchBar"))
      )
      perform_search()
      print(pd.DataFrame(scrape_details()))
  finally:
    if driver:
        driver.quit()

if __name__ == "__main__":
    main()
# Out:
#                            title                                 company  \
# 0      Hiring For Data Scientist                 divya staffing solution
# 1         Data Scientist Opening                      renuka interprises
# 2         Data Scientist Opening                      renuka interprises
# 3     Data Scientist Recruitment                     radhika enterprises
# 4                 Data Scientist                           techno endura
# 5              ML Data Scientist  gujarat facility services hiring fo...
# 6            Azure Data engineer  capgemini technology services india...
# 7  Data Scientist Urgent Vacancy                      renuka interprises
# 8     Data Scientist Recruitment                      renuka interprises
# 9     Data Scientist Recruitment                      renuka interprises
#
#     location   experience
# 0  Bangalore   0 to 4 Yrs
# 1  Bangalore   0 to 4 Yrs
# 2  Bangalore   0 to 4 Yrs
# 3  Bangalore   0 to 4 Yrs
# 4  Bangalore   0 to 2 Yrs
# ...

# %%
# Question 3

import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
import time
import pandas as pd

driver = None
def init_driver(url):
  global driver
  try:
    options = webdriver.ChromeOptions()
    options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36")
    driver = webdriver.Chrome(options=options)
    driver.get(url)
  except Exception as e:
    print("Error:", e)
  return driver

def perform_search():
  input_box = driver.find_element(By.CSS_SELECTOR, "#webSearchBar input")
  input_box.click()
  time.sleep(1)
  input_box = driver.find_element(By.ID, "id_q")
  input_box.send_keys("Data Scientist")
  driver.find_element(By.XPATH, "//button[starts-with(text(), 'Search')]").click()
  try:
    WebDriverWait(driver, 3).until(
      EC.presence_of_element_located((By.CLASS_NAME, "register_close"))
    )
    close_btn = driver.find_element(By.CLASS_NAME, "register_close")
    close_btn.click()
  except:
    pass
  WebDriverWait(driver, 30).until(
    EC.presence_of_element_located((By.ID, "fb-root"))
  )
  driver.find_element(By.XPATH, "//button[starts-with(text(), 'More filters')]").click()
  time.sleep(5)
  input_box = driver.find_element(By.CSS_SELECTOR, "input[placeholder='Search Location']")
  input_box.send_keys("Delhi")
  driver.find_element(By.XPATH, "//label[starts-with(text(), 'Delhi')]").click()
  driver.find_element(By.XPATH, "//li[starts-with(text(), 'Salary')]").click()
  driver.find_element(By.XPATH, "//label[starts-with(text(), '3 To ')]").click()
  driver.find_element(By.XPATH, "//button[starts-with(text(), 'Show Results')]").click()
  return None

def scrape_details():
  rows = driver.find_elements(By.CLASS_NAME, "jobCard")
  result = {
    "title": [],
    "company": [],
    "location": [],
    "experience": []
  }
  for index, row in enumerate(rows):
    if index >= 10:
      break
    job_title = row.find_element(By.TAG_NAME, "h2").text.strip()
    company_name = row.find_element(By.CLASS_NAME, "jobCard_jobCard_cName__mYnow").text.strip()
    job_location = re.sub(r'[^a-zA-Z]', '', (row.find_element(By.CLASS_NAME, "jobCard_locationIcon__zrWt2").text).strip())
    job_experience = row.find_element(By.CLASS_NAME, "jobCard_jobIcon__3FB1t").text.strip()
    result["title"].append(job_title)
    result["company"].append(company_name)
    result["location"].append(job_location)
    result["experience"].append(job_experience)
  return result  

def main():
  try:
    init_driver("https://www.shine.com/")
    if driver:
      WebDriverWait(driver, 30).until(
        EC.presence_of_element_located((By.ID, "webSearchBar"))
      )
      perform_search()
      print(pd.DataFrame(scrape_details()))
  finally:
    if driver:
        driver.quit()

if __name__ == "__main__":
    main()
# Out:
#                                                title  \
# 0                  Sr. Data Scientist/Data Scientist
# 1                                Lead Data Scientist
# 2                                     Data Scientist
# 3                              Branch Manager Agency
# 4                              Branch Manager Agency
# 5                  Area Talent Acquisition Executive
# 6  Urgent Hiring For International Voice and Non ...
# 7  Hiring for Talent Acquisition Manager for a le...
# 8                      Key Account Manager-IDFC Bank
# 9  Associate, Senior Associate , Principal Associate
#
#                                   company          location   experience
# 0                               fountain9  OtherMaharashtra   2 to 6 Yrs
# 1                                  tavant    OtherKarnataka   5 to 8 Yrs
# 2  aditya birla sun life insurance com...          Guwahati   0 to 2 Yrs
# 3  aditya birla sun life insurance com...    OtherTamilNadu  6 to 11 Yrs
# ...

# %%
# Question 4

import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
import time
import pandas as pd

driver = None
def init_driver(url):
  global driver
  try:
    options = webdriver.ChromeOptions()
    options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36")
    driver = webdriver.Chrome(options=options)
    driver.get(url)
  except Exception as e:
    print("Error:", e)
  return driver

def perform_search():
  try:
    WebDriverWait(driver, 3).until(
      EC.presence_of_element_located((By.CSS_SELECTOR, "span[role='button']"))
    )
    close_btn = driver.find_element(By.CSS_SELECTOR, "span[role='button']")
    close_btn.click()
  except:
    pass
  input_box = driver.find_element(By.CSS_SELECTOR, 'input[title="Search for Products, Brands and More"]')
  input_box.send_keys("sunglasses")
  input_box.send_keys(Keys.ENTER)
  return None

def scrape_details():
  result = {
    "brand": [],
    "desc": [],
    "price": [],
  }
  def scrape_page():
    rows = driver.find_elements(By.XPATH, "//*[@data-id]")
    for row in rows:
      card = row.find_element(By.CSS_SELECTOR, "div div")
      desc = card.find_element(By.CSS_SELECTOR, "a.IRpwTa").text.strip()
      brand = card.find_element(By.CSS_SELECTOR, "div._2WkVRV").text.strip()
      price = card.find_element(By.CSS_SELECTOR, "div._30jeq3").text.strip()
      result["brand"].append(brand)
      result["desc"].append(desc)
      result["price"].append(price)

  while(len(result["brand"]) < 100):
    scrape_page()
    WebDriverWait(driver, 3).until(
      EC.presence_of_element_located((By.XPATH, "//span[text() = 'Next']"))
    )
    driver.find_element(By.XPATH, "//span[text() = 'Next']").click()
    time.sleep(2)
  result["brand"] = result["brand"][:100]
  result["desc"] = result["desc"][:100]
  result["price"] = result["price"][:100]
  return result

def main():
  try:
    init_driver("https://www.flipkart.com/")
    if driver:
      perform_search()
      print(pd.DataFrame(scrape_details()))
  finally:
    if driver:
        driver.quit()

if __name__ == "__main__":
    main()
# Out:
#             brand                                               desc price
# 0   VINCENT CHASE  by Lenskart Polarized, UV Protection Round Sun...  ₹879
# 1   VINCENT CHASE  by Lenskart Polarized, UV Protection Round Sun...  ₹879
# 2            SRPM             UV Protection Wayfarer Sunglasses (50)  ₹169
# 3       Elligator   UV Protection, Mirrored Wayfarer Sunglasses (52)  ₹169
# 4        Fastrack             UV Protection Wayfarer Sunglasses (58)  ₹599
# ..            ...                                                ...   ...
# 95       Fastrack                 Polarized Wayfarer Sunglasses (55)  ₹629
# 96         AISLIN  Toughened Glass Lens, UV Protection Aviator, W...  ₹562
# 97      ROYAL SON  Polarized, UV Protection Wayfarer, Retro Squar...  ₹719
# 98  VINCENT CHASE  by Lenskart Polarized, UV Protection Round Sun...  ₹749
# 99      Elligator   UV Protection Wayfarer, Wayfarer Sunglasses (52)  ₹249
#
# [100 rows x 3 columns]

# %%
# Question 5

import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
import time
import pandas as pd

driver = None
def init_driver(url):
  global driver
  try:
    options = webdriver.ChromeOptions()
    options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36")
    driver = webdriver.Chrome(options=options)
    driver.get(url)
  except Exception as e:
    print("Error:", e)
  return driver

def perform_search():
  try:
    WebDriverWait(driver, 3).until(
      EC.presence_of_element_located((By.CSS_SELECTOR, "span[role='button']"))
    )
    close_btn = driver.find_element(By.CSS_SELECTOR, "span[role='button']")
    close_btn.click()
  except:
    pass
  input_box = driver.find_element(By.CSS_SELECTOR, 'input[title="Search for Products, Brands and More"]')
  input_box.send_keys("sunglasses")
  input_box.send_keys(Keys.ENTER)
  return None

def scrape_details():
  result = {
    "rating": [],
    "review": [],
    "summary": [],
  }
  def scrape_page():
    rows = driver.find_elements(By.CSS_SELECTOR, "div.col._2wzgFH.K0kLPL")
    for row in rows:
      rating = row.find_element(By.CSS_SELECTOR, "div._3LWZlK._1BLPMq").text.strip()
      review = row.find_element(By.CSS_SELECTOR, "p._2-N8zT").text.strip()
      summary = row.find_element(By.CSS_SELECTOR, "div.t-ZTKy").text.strip()
      result["rating"].append(rating)
      result["review"].append(review)
      result["summary"].append(summary)

  while(len(result["rating"]) < 100):
    scrape_page()
    WebDriverWait(driver, 3).until(
      EC.presence_of_element_located((By.XPATH, "//span[text() = 'Next']"))
    )
    driver.find_element(By.XPATH, "//span[text() = 'Next']").click()
    time.sleep(2)
  result["rating"] = result["rating"][:100]
  result["review"] = result["review"][:100]
  result["summary"] = result["summary"][:100]
  return result

def main():
  try:
    init_driver("https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market")
    if driver:
      print(pd.DataFrame(scrape_details()))
  finally:
    if driver:
        driver.quit()

if __name__ == "__main__":
    main()
# Out:
#    rating               review  \
# 0       5     Perfect product!
# 1       5    Worth every penny
# 2       5  Best in the market!
# 3       5       Classy product
# 4       5            Wonderful
# ..    ...                  ...
# 95      5            Wonderful
# 96      5       Classy product
# 97      3                 Good
# 98      5            Excellent
# 99      5            Brilliant
#
#                                               summary
# 0                                        Photos super
# 1   Feeling awesome after getting the delivery of ...
# 2                                         Good Camera
# 3   Camera is awesome\nBest battery backup\nA perf...
# 4                              This is amazing at all
# ..                                                ...
# 95                                     Quality camera
# 96                 Outstanding performance this phone
# 97               only the name worth it with d price.
# ...

# %%
# Question 6

import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
import time
import pandas as pd

driver = None
def init_driver(url):
  global driver
  try:
    options = webdriver.ChromeOptions()
    options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36")
    driver = webdriver.Chrome(options=options)
    driver.get(url)
  except Exception as e:
    print("Error:", e)
  return driver

def perform_search():
  try:
    WebDriverWait(driver, 3).until(
      EC.presence_of_element_located((By.CSS_SELECTOR, "span[role='button']"))
    )
    close_btn = driver.find_element(By.CSS_SELECTOR, "span[role='button']")
    close_btn.click()
  except:
    pass
  input_box = driver.find_element(By.CSS_SELECTOR, 'input[title="Search for Products, Brands and More"]')
  input_box.send_keys("sneakers")
  input_box.send_keys(Keys.ENTER)
  return None

def scrape_details():
  result = {
    "brand": [],
    "desc": [],
    "price": [],
  }
  def scrape_page():
    rows = driver.find_elements(By.XPATH, "//*[@data-id]")
    for row in rows:
      card = row.find_element(By.CSS_SELECTOR, "div div")
      desc = card.find_element(By.CSS_SELECTOR, "a.IRpwTa").text.strip()
      brand = card.find_element(By.CSS_SELECTOR, "div._2WkVRV").text.strip()
      price = card.find_element(By.CSS_SELECTOR, "div._30jeq3").text.strip()
      result["brand"].append(brand)
      result["desc"].append(desc)
      result["price"].append(price)

  while(len(result["brand"]) < 100):
    scrape_page()
    WebDriverWait(driver, 3).until(
      EC.presence_of_element_located((By.XPATH, "//span[text() = 'Next']"))
    )
    driver.find_element(By.XPATH, "//span[text() = 'Next']").click()
    time.sleep(2)
  result["brand"] = result["brand"][:100]
  result["desc"] = result["desc"][:100]
  result["price"] = result["price"][:100]
  return result

def main():
  try:
    init_driver("https://www.flipkart.com/")
    if driver:
      perform_search()
      print(pd.DataFrame(scrape_details()))
  finally:
    if driver:
        driver.quit()

if __name__ == "__main__":
    main()
# Out:
#           brand                                               desc   price
# 0   kardam&sons  Fashionable Canvas Casual Partywear Outdoor wh...    ₹399
# 1        BRUTON             2 Combo Sneaker Shoes Sneakers For Men    ₹575
# 2      URBANBOX  Trending Stylish Casual Outdoor Shoes Sneakers...    ₹448
# 3          ATOM                    Alpha Predator Sneakers For Men  ₹1,355
# 4          aadi  Synthetic Leather |Lightweight|Comfort|Summer|...    ₹339
# ..          ...                                                ...     ...
# 95        asian  Casual Sneaker Shoes For Women | Stylish and C...    ₹745
# 96       REFOAM                                   Sneakers For Men    ₹759
# 97        asian  Trendy-02 Blue Sneakers,Casual,Loafers, Sneake...    ₹622
# 98       lejano                                   Sneakers For Men    ₹448
# 99         PUMA                         Puma Buzz Sneakers For Men  ₹1,299
#
# [100 rows x 3 columns]

# %%
# Question 7

import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
import time
import pandas as pd

driver = None
def init_driver(url):
  global driver
  try:
    options = webdriver.ChromeOptions()
    options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36")
    driver = webdriver.Chrome(options=options)
    driver.get(url)
  except Exception as e:
    print("Error:", e)
  return driver

def perform_search():
  input_box = driver.find_element(By.ID, 'twotabsearchtextbox')
  input_box.send_keys("Laptop")
  driver.find_element(By.ID, "nav-search-submit-button").click()
  WebDriverWait(driver, 3).until(
    EC.presence_of_element_located((By.XPATH, "//a[text() = 'Next']"))
  )
  driver.find_element(By.XPATH, "//span[text() = 'Intel Core i7']").click()
  WebDriverWait(driver, 3).until(
    EC.presence_of_element_located((By.XPATH, "//a[text() = 'Next']"))
  )
  return None

def scrape_details():
  result = {
    "title": [],
    "rating": [],
    "price": [],
  }
  rows = driver.find_elements(By.CSS_SELECTOR, 'div[data-component-type="s-search-result"]')
  for row in rows:
    title = row.find_element(By.CSS_SELECTOR, "div[data-cy='title-recipe']").text.strip()
    rating = "NA"
    try:
      rating = row.find_element(By.CSS_SELECTOR, "a.a-popover-trigger.a-declarative").text.strip()
    except:
      pass
    price = row.find_element(By.CSS_SELECTOR, "span.a-price-whole").text.strip()
    result["title"].append(title)
    result["rating"].append(rating)
    result["price"].append(price)

  return result

def main():
  try:
    init_driver("https://www.amazon.in/")
    if driver:
      perform_search()
      print(pd.DataFrame(scrape_details()))
  finally:
    if driver:
        driver.quit()

if __name__ == "__main__":
    main()
# Out:
#                                                 title rating     price
# 0   Lenovo ThinkBook 15 Intel 12th Gen Core i7 15....     NA    57,990
# 1   ASUS TUF Gaming F15, 15.6"(39.62 cms) FHD 144H...           81,999
# 2   Acer Travelmate Business Laptop Intel Core i7-...           49,990
# 3   Lenovo IdeaPad Slim 3 Intel Core i7 12th Gen 1...           62,490
# 4   Dell G15 5530 Gaming Laptop, Intel i7-13650HX/...           99,990
# 5   Lenovo ThinkPad X1 Yoga Intel Core i7 11th Gen...     NA  1,96,000
# 6   MSI Modern 14, Intel 12th Gen. i7-1255U, 36CM ...           54,010
# 7   HP Pavilion X360 11th Gen Intel Core i7 14" (3...           67,990
# 8   Samsung Galaxy Book3 Core i7 13th Gen 1355U - ...           81,990
# 9   HP Laptop 15s, 12th Gen Intel Core i7-1255U, 1...           67,490
# 10  Lenovo ThinkPad E14 Intel Core i7 12th Gen 14"...           93,990
# 11  GIGABYTE G5 MF-G2IN313SH Gaming Laptop Intel C...           79,636
# ...

# %%
# Question 8

import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
import time
import pandas as pd

driver = None
def init_driver(url):
  global driver
  try:
    options = webdriver.ChromeOptions()
    options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36")
    driver = webdriver.Chrome(options=options)
    driver.get(url)
  except Exception as e:
    print("Error:", e)
  return driver

def perform_search():
  driver.find_element(By.XPATH, "//a[text() = 'Top Quotes']").click()
  WebDriverWait(driver, 3).until(
    EC.presence_of_element_located((By.XPATH, "//a[contains(text(), 'Next')]"))
  )
  return None

def scrape_details():
  result = {
    "quote": [],
    "author": [],
    "type": [],
  }
  def scrape_page():
    rows = driver.find_elements(By.CSS_SELECTOR, 'ul.list-quotes li')
    for row in rows:
      quote = row.find_element(By.CSS_SELECTOR, "a.title").text.strip()
      author = row.find_element(By.CSS_SELECTOR, "div.author").text.strip()
      type = row.find_element(By.CSS_SELECTOR, "div.tags").text.strip()
      result["quote"].append(quote)
      result["author"].append(author)
      result["type"].append(type)
  
  while(len(result["quote"]) < 1000):
    scrape_page()
    if (len(result["quote"]) >= 1000):
      break
    driver.find_element(By.XPATH, "//a[contains(text(), 'Next')]").click()
    time.sleep(5)

  return result

def main():
  try:
    init_driver("https://www.azquotes.com/")
    if driver:
      perform_search()
      print(pd.DataFrame(scrape_details()))
  finally:
    if driver:
        driver.quit()

if __name__ == "__main__":
    main()
# Out:
#                                                  quote              author  \
# 0    The essence of strategy is choosing what not t...      Michael Porter
# 1    One cannot and must not try to erase the past ...          Golda Meir
# 2    Patriotism means to stand by the country. It d...  Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...      Nelson Mandela
# 4    You have to love a nation that celebrates its ...        Erma Bombeck
# ..                                                 ...                 ...
# 995  Regret for the things we did can be tempered b...    Sydney J. Harris
# 996  America... just a nation of two hundred millio...  Hunter S. Thompson
# 997  For every disciplined effort there is a multip...            Jim Rohn
# 998  The spiritual journey is individual, highly pe...            Ram Dass
# 999  The mind is not a vessel to be filled but a fi...            Plutarch
#
#                                          type
# ...

# %%
# Question 9

import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
import time
import pandas as pd

driver = None
def init_driver(url):
  global driver
  try:
    options = webdriver.ChromeOptions()
    options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36")
    driver = webdriver.Chrome(options=options)
    driver.get(url)
  except Exception as e:
    print("Error:", e)
  return driver

def perform_search():
  driver.find_element(By.XPATH, "//a[text() = 'GK']").click()
  WebDriverWait(driver, 3).until(
    EC.presence_of_element_located((By.XPATH, "//a[contains(text(), 'List of Prime Ministers of India')]"))
  )
  driver.find_element(By.XPATH, "//a[contains(text(), 'List of Prime Ministers of India')]").click()
  WebDriverWait(driver, 3).until(
    EC.presence_of_element_located((By.CSS_SELECTOR, 'table tbody tr'))
  )
  return None

def scrape_details():
  result = {
    "name": [],
    "born_dead": [],
    "remark": [],
  }
  root = driver.find_element(By.CLASS_NAME, "TableData")
  rows = root.find_elements(By.CSS_SELECTOR, 'table tbody tr')[1:]
  for row in rows:
    name = row.find_elements(By.TAG_NAME, "td")[1].text.strip()
    born_dead = row.find_elements(By.TAG_NAME, "td")[2].text.strip()
    remark = row.find_elements(By.TAG_NAME, "td")[4].text.strip()
    result["name"].append(name)
    result["born_dead"].append(born_dead)
    result["remark"].append(remark)
  return result

def main():
  try:
    init_driver("https://www.jagranjosh.com/")
    if driver:
      perform_search()
      print(pd.DataFrame(scrape_details()))
  finally:
    if driver:
        driver.quit()

if __name__ == "__main__":
    main()
# Out:
#                            name     born_dead  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
# 18                Narendra Modi   (born 1950)
#
# ...

# %%
# Question 10

import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
import time
import pandas as pd

driver = None
def init_driver(url):
  global driver
  try:
    options = webdriver.ChromeOptions()
    options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36")
    driver = webdriver.Chrome(options=options)
    driver.get(url)
  except Exception as e:
    print("Error:", e)
  return driver

def perform_search():
  driver.find_element(By.ID, "search_input").send_keys("50 most expensive cars")
  driver.find_element(By.ID, "search_input").send_keys(Keys.ENTER)
  WebDriverWait(driver, 10).until(
    EC.presence_of_element_located((By.XPATH, "//h1[contains(text(), 'Search')]"))
  )
  driver.find_element(By.XPATH, "//a[contains(text(), '50 Most Expensive Cars In The World')]").click()
  WebDriverWait(driver, 10).until(
    EC.presence_of_element_located((By.XPATH, "//h1[contains(text(), '50 Most Expensive Cars In The World')]"))
  )
  return None

def scrape_details():
  l = driver.find_element(By.XPATH, "//h3[contains(text(), 'Most Expensive Cars In The World')]/following-sibling::ul") 
  result = {
    "name": [],
    "price": []
  }
  rows = l.find_elements(By.TAG_NAME, "li")
  for row in rows:
    text = row.text.strip()
    result["name"].append(text.split("$")[0])
    result["price"].append("$" + text.split("$")[1])

  return result

def main():
  try:
    init_driver("https://www.motor1.com/")
    if driver:
      perform_search()
      print(pd.DataFrame(scrape_details()))
  finally:
    if driver:
        driver.quit()

if __name__ == "__main__":
    main()
# Out:
#                                      name           price
# 0                  Aston Martin Valour -     $1.5 Million
# 1                         Mclaren Elva -     $1.7 Million
# 2                          Czinger 21C -     $1.7 Million
# 3                        Ferrari Monza -     $1.7 Million
# 4                   Gordon Murray T.33 -     $1.7 Million
# 5                    Koenigsegg Gemera -     $1.7 Million
# 6                         McLaren Elva -     $1.7 Million
# 7                          Zenvo TSR-S -     $1.7 Million
# 8                   Hennessey Venom F5 -     $1.8 Million
# 9                      Bentley Bacalar -     $1.9 Million
# 10        Hispano Suiza Carmen Boulogne:     $1.9 Million
# 11               Bentley Mulliner Batur:     $2.0 Million
# 12                         Deus Vayanne:     $2.0 Million
# 13                         SSC Tuatara -     $2.0 Million
# 14                         Lotus Evija -     $2.1 Million
# ...
